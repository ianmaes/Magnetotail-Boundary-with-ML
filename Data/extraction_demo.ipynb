# %% [markdown]
# #### **Demo script for data plotting.**

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.colors import LogNorm
import pyspedas
from pyspedas import tplot, options, get_data
from datetime import datetime, UTC
from data_class import LoadArtemis, plot_electron_spectrogram
import data_cleaning
from copy import deepcopy

# Create the CDAWeb interface object
cdaweb_obj = pyspedas.CDAWeb()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_class = LoadArtemis(start_time = '2012-12-26 00:00:00', end_time='2012-12-29 23:59:00')
# Out:
# 07-Jun-25 19:12:03: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2012\thb_l2_esa_20121225_v01.cdf
# 07-Jun-25 19:12:05: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2012\thb_l2_esa_20121226_v01.cdf
# 07-Jun-25 19:12:07: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2012\thb_l2_esa_20121227_v01.cdf
# 07-Jun-25 19:12:08: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2012\thb_l2_esa_20121228_v01.cdf
# 07-Jun-25 19:12:09: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2012\thb_l2_esa_20121229_v01.cdf
# 07-Jun-25 19:12:09: Downloaded 5 CDF files.
# ...

# %%
test_data_class = deepcopy(data_class)

# %%
test_data_class.reset_data()

# %%
test_data_class.convert_min_delta_all(start_time = '2012-12-26 07:30:00', end_time='2012-12-29 06:00:00', dt_method='max', custom_time_delta=587.7814736366272
                                      )
# Out:
# Variable 'B_electric_field_gsm' contains only NaN values and has been removed.
# here
# here
# here
# here
# here
# [-253.73419189 -629.33093262 -281.10635376 ...  -85.182724    -71.33336639
#  -102.13220978]
# [  57.39560318 -119.16616058   42.84039307 ...    9.2272377    12.03779221
#    15.70721436]
# [  -9.13029194 -404.1383667    17.97282219 ...   23.28852272  -23.49059677
#     1.35482049]
# here
# here
# [-251.04292297 -268.34542847 -257.18423462 ...  -90.19710541  -84.477005
#   -86.20345306]
# [47.11764145 51.94742203 49.44599915 ... 17.33305359  5.62339973
#   4.64833832]
# [-7.07938957 -4.67582226  0.63805771 ... 19.72877693 18.54675674
#  16.21943855]
# here
# here
# here
# here
# [  0.1839269    0.323874    -0.19800256 ... -10.821866   -11.027076
#  -11.243988  ]
# [ 1.3380433  1.0533159  2.1679668 ... -0.8902781 -0.6451618 -0.6567376]
# [ 0.21501651  1.1301832   0.2987272  ... -0.2655048  -0.23646758
#  -0.24205214]

# %%
test_data_class.data['B_ion_eflux']['data']['times'][1] - test_data_class.data['B_ion_eflux']['data']['times'][0]
# Out:
# numpy.timedelta64(529830709504,'ns')

# %%
plot_electron_spectrogram(test_data_class.data['B_ion_eflux']['data']['y'], 
                          test_data_class.data['B_ion_eflux']['data']['times'],
                          test_data_class.data['B_ion_eflux']['data']['v'],
                          vmin=1e2,
                          vmax=1e8,
                          figsize=(8, 4),
                          title='Artemis B Ion energy-time spectrogram'
                         )
# Out:
# 07-Jun-25 19:49:02: c:\Users\ianma\anaconda3\envs\deep_learning\Lib\site-packages\traitlets\traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_data_class.extract_to_HDF5('training_data/test.h5')
# Out:
# Data saved to training_data/test.h5 in group session_0022
