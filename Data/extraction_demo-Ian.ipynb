# %% [markdown]
# #### **Demo script for data plotting.**

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.colors import LogNorm
import pyspedas
from pyspedas import tplot, options, get_data
from datetime import datetime, UTC
from data_class import LoadArtemis, plot_electron_spectrogram
import data_cleaning
from copy import deepcopy

# Create the CDAWeb interface object
cdaweb_obj = pyspedas.CDAWeb()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_class = LoadArtemis(start_time='2013-04-24 00:00:00', end_time='2013-04-28 00:00:00')
# Out:
# 08-Jul-25 11:13:50: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2013\thb_l2_esa_20130423_v01.cdf
# 08-Jul-25 11:13:51: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2013\thb_l2_esa_20130424_v01.cdf
# 08-Jul-25 11:13:52: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2013\thb_l2_esa_20130425_v01.cdf
# 08-Jul-25 11:13:52: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2013\thb_l2_esa_20130426_v01.cdf
# 08-Jul-25 11:13:53: File is current: C:\Users\ianma\OneDrive\Documents\Thesis\Magnetotail-Boundary-with-ML\Data\cdaweb\themis\thb\l2\esa\2013\thb_l2_esa_20130427_v01.cdf
# ...

# %%
test_data_class = deepcopy(data_class)

# %%
test_data_class.reset_data()

# %%
test_data_class.convert_min_delta_all(start_time='2013-04-23 12:00:00', end_time='2013-04-28 12:00:00', dt_method='max', custom_time_delta=678.5134313106537)
# Out:
# Variable 'B_electric_field_gsm' contains only NaN values and has been removed.
# Preprocessing B_electron_eflux
# Preprocessing B_electron_avgtemp
# Preprocessing B_ion_velocity_gsm
# Preprocessing B_ion_avgtemp
# Preprocessing B_electron_density
# Preprocessing B_ion_vthermal
# Preprocessing B_ion_eflux
# Preprocessing B_electron_vthermal
# Preprocessing B_electron_velocity_gsm
# Preprocessing B_ion_density
# Preprocessing B_magnetic_field_gsm

# %%
test_data_class.data.keys()
# Out:
# dict_keys(['B_electron_eflux', 'B_electron_avgtemp', 'B_ion_velocity_gsm', 'B_ion_avgtemp', 'B_electron_density', 'B_ion_vthermal', 'B_ion_eflux', 'B_electron_vthermal', 'B_electron_velocity_gsm', 'B_ion_density', 'B_magnetic_field_gsm'])

# %%
test_data_class.plot_variables(variable_names=['B_electron_avgtemp'])
# Out:
# 08-Jul-25 11:39:20: c:\Users\ianma\miniconda3\envs\deep_learning\Lib\site-packages\traitlets\traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plot_electron_spectrogram(test_data_class.data['B_ion_eflux']['data']['y'], 
                          test_data_class.data['B_ion_eflux']['data']['times'],
                          test_data_class.data['B_ion_eflux']['data']['v'],
                          vmin=1e3,
                          figsize=(10, 6)
                         )
# Out:
# 08-Jul-25 11:39:09: c:\Users\ianma\miniconda3\envs\deep_learning\Lib\site-packages\traitlets\traitlets.py:1385: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# NavigationToolbar2WebAgg.__init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   warn(
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# test_data_class.extract_to_HDF5('testing_data/test.h5')
# Out:
# Data saved to testing_data/test.h5 in group session_0000
