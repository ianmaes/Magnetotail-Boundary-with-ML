# %%
from copy import deepcopy

# %%
lst = [3, 2, 8, 7, 9]

# %%
def gesorteerd(lst): 
    if len(lst) < 2:     
        return True
    
    for i in range(len(lst)):
        huidig_getal = lst[i]

        volgend_getal = lst[i + 1]
        print(huidig_getal)
        print(volgend_getal)
        if huidig_getal < volgend_getal:
            return False

    return True

# %%
def wissel(lst, index1, index2):
    a = lst[index1]
    b = lst[index2]

    lst[index1] = b
    lst[index2] = a

    return lst

# %%
def selection_sort(lst):
    if len(lst) < 2
        return lst

    kleinste_index = 0

    for i in range(len(lst)):
        kleinste_index = index_lijst
        kleinste = lst[index_lijst]

        for i in range(kleinste_index, len(lst)):
            if lst[i] < kleinste:
                kleinste = lst[i]
                kleinste_index = i
        
        lst = wissel(lst, index_lijst, kleinste_index)

        index_lijst += 1

    return lst

# %%
lst_new = deepcopy(lst)

# %%
a = [0] * 5

# %%
print(a)
# Out:
# [0, 0, 0, 0, 0]

# %%
def nieuwe_lijst(lst):
    lst_new = []

    for i in range(len(lst)):
        lst_new.append(lst[i])

    return lst_new

# %%
lst_new = nieuwe_lijst(lst)

# %%
lst_new[2] = 123

# %%
print(lst)
# Out:
# [3, 2, 8, 7, 9]

# %%
lst_new
# Out:
# [3, 2, 123, 7, 9]

# %%
lst_nieuw = selection_sort(lst)
print(lst_nieuw)
# Out:
# [2, 3, 7, 8, 9]

# %%
lst.sort()

# %%
print(lst)
# Out:
# [2, 3, 7, 8, 9]
